# %%
import requests
import pickle as pk

url = "https://v3.football.api-sports.io/leagues"

payload={}
headers = {
  'x-apisports-key': '68cbc11ae9806f51bbebfc6bcf65feff',
}

response = requests.request("GET", url, headers=headers, data=payload)
# Out:
# c:\Users\bodyk\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.4.0.post2)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(

# %%
print(response.json.)
# Out:
# <bound method Response.json of <Response [200]>>
