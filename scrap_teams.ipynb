# %%
import pandas as pd

# %%
data = pd.read_csv("Scrapped_data\standings_data.csv")
squad_data = data[['Squad', "League"]]

# %%
squad_data.drop_duplicates(inplace=True)

# %%
squad_data
# Out:
#                  Squad          League
# 0       Leicester City  Premier League
# 1              Arsenal  Premier League
# 2    Tottenham Hotspur  Premier League
# 3      Manchester City  Premier League
# 4       Manchester Utd  Premier League
# ..                 ...             ...
# 886               Lens         Ligue 1
# 916      Clermont Foot         Ligue 1
# 936            Auxerre         Ligue 1
# 937            Ajaccio         Ligue 1
# 954           Le Havre         Ligue 1
#
# [160 rows x 2 columns]

# %%
squad_data.to_csv('Scrapped_data/teams_table.csv')
